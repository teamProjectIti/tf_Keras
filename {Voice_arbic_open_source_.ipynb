# %% [markdown]
# <a href="https://colab.research.google.com/github/teamProjectIti/tf_Keras/blob/main/%7BVoice_arbic_open_source_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from kani_tts import KaniTTS
from IPython.display import Audio, display

# تحميل الموديل
model = KaniTTS('nineninesix/kani-tts-400m-ar')

# النص
# text = "مرحبا بك يا بشوي. كيف يمكنني مساعدتك اليوم؟"
text = "ايه يامي ايه الاخبار والمعلم نادي ايه اخباره هتقابلي خالي اسحاق انهارده"

# استدعاء الموديل
audio, _ = model(text)

# تشغيل الصوت
display(Audio(audio, rate=model.sample_rate, autoplay=True))
# Out:
# ╔════════════════════════════════════════════════════════════╗
# ║                                                            ║
# ║                   N I N E N I N E S I X  😼                ║
# ║                                                            ║
# ╚════════════════════════════════════════════════════════════╝
#
#               /\_/\
#              ( o.o )
#               > ^ <
#
# ──────────────────────────────────────────────────────────────
#   Model: nineninesix/kani-tts-400m-ar
#   Device: GPU (CUDA)
#   Mode: Single-speaker
#
#   Configuration:
#     • Sample Rate: 22050 Hz
#     • Temperature: 1
#     • Top-p: 0.95
#     • Max Tokens: 1200
#     • Repetition Penalty: 1.1
# ──────────────────────────────────────────────────────────────
#
#   Ready to generate speech! 🎵
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
# ...
